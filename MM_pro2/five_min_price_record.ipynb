# %% [markdown]
# Importing Exchange data from CoinGecko to create giant df

# %%
import datetime
import time
import json
import requests
import pandas as pd

# %%
coin_id = ['bitcoin', 'ethereum', 'tether', 'usd-coin', 'binancecoin']
exchange = ['binance', 'coinbase', 'okx', 'huobi']
 
def create_exchange_df(exchange, coin_id):
    for x in exchange:
        exchange_data = get_coin_data(x, coin_id)
        exchange_df = pd.DataFrame(exchange_data)
    return exchange_df


def get_coin_data (exchange, coin_id):
    for coin in coin_id:
        url = f"https://api.coingecko.com/api/v3/exchanges/{exchange}/tickers?coin_ids={coin}"
        response = requests.get(url)
        data = response.json()
        print (data)
#         timestamp_list = []
#         price_list = []
#         volume_list = []
#         price_spread = []
#         for row in data['tickers'] :
#             # dt = datetime.datetime.fromtimestamp(row[0]/ 1000)
#             # formatted_time = dt.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
#             # timestamp_list.append(formatted_time)
#             # price_list.append(row[1])
            
    # raw_data = {'timestamp': timestamp_list, 'price' : price_list}
    # df = pd.DataFrame(raw_data, columns=['timestamp','price'])
    # df = df.reset_index()
    # df = df.set_index('timestamp')
    # #pd.options.display.float_format = '{:.2f}'.format
        
    # return df
create_exchange_df(exchange, coin_id)
# Out:
# {'name': 'Binance', 'tickers': [{'base': 'BTC', 'target': 'USDT', 'market': {'name': 'Binance', 'identifier': 'binance', 'has_trading_incentive': False}, 'last': 17800.59, 'volume': 280473.08619644307, 'converted_last': {'btc': 0.99937457, 'eth': 13.439331, 'usd': 17797.39}, 'converted_volume': {'btc': 280298, 'eth': 3769371, 'usd': 4991689701}, 'trust_score': 'green', 'bid_ask_spread_percentage': 0.010393, 'timestamp': '2022-12-14T01:06:45+00:00', 'last_traded_at': '2022-12-14T01:06:45+00:00', 'last_fetch_at': '2022-12-14T01:06:45+00:00', 'is_anomaly': False, 'is_stale': False, 'trade_url': 'https://www.binance.com/en/trade/BTC_USDT?ref=37754157', 'token_info_url': None, 'coin_id': 'bitcoin', 'target_coin_id': 'tether'}, {'base': 'BTC', 'target': 'BUSD', 'market': {'name': 'Binance', 'identifier': 'binance', 'has_trading_incentive': False}, 'last': 17822.53, 'volume': 178409.9879506968, 'converted_last': {'btc': 1.000265, 'eth': 13.44425, 'usd': 17806.9}, 'converted_volume': {'btc': 178457, 'eth': 2398589, 'usd': 3176928531}, 'trust_score': 'green', 'bid_ask_spread_percentage': 0.011291, 'timestamp': '2022-12-14T01:00:49+00:00', 'last_traded_at': '2022-12-14T01:00:49+00:00', 'last_fetch_at': '2022-12-14T01:00:49+00:00', 'is_anomaly': False, 'is_stale': False, 'trade_url': 'https://www.binance.com/en/trade/BTC_BUSD?ref=37754157', 'token_info_url': None, 'coin_id': 'bitcoin', 'target_coin_id': 'binance-usd'}, {'base': 'BTC', 'target': 'EUR', 'market': {'name': 'Binance', 'identifier': 'binance', 'has_trading_incentive': False}, 'last': 16732.7, 'volume': 4177.705469771394, 'converted_last': {'btc': 0.99898396, 'eth': 13.429985, 'usd': 17784.57}, 'converted_volume': {'btc': 4173, 'eth': 56107, 'usd': 74298688}, 'trust_score': 'green', 'bid_ask_spread_percentage': 0.020313, 'timestamp': '2022-12-14T00:54:50+00:00', 'last_traded_at': '2022-12-14T00:54:50+00:00', 'last_fetch_at': '2022-12-14T00:54:50+00:00', 'is_anomaly': False, 'is_stale': False, 'trade_url': 'https://www.binance.com/en/trade/BTC_EUR?ref=37754157', 'token_info_url': None, 'coin_id': 'bitcoin'}, {'base': 'BTC', 'target': 'GBP', 'market': {'name': 'Binance', 'identifier': 'binance', 'has_trading_incentive': False}, 'last': 14233.84, 'volume': 1325.024231686783, 'converted_last': {'btc': 0.98718552, 'eth': 13.269001, 'usd': 17574.96}, 'converted_volume': {'btc': 1308, 'eth': 17582, 'usd': 23287253}, 'trust_score': 'green', 'bid_ask_spread_percentage': 0.015063, 'timestamp': '2022-12-14T00:52:11+00:00', 'last_traded_at': '2022-12-14T00:52:11+00:00', 'last_fetch_at': '2022-12-14T00:52:11+00:00', 'is_anomaly': False, 'is_stale': False, 'trade_url': 'https://www.binance.com/en/trade/
 'market': {'name': 'Binance', 'identifier': 'binance', 'has_trading_incentive': False}, 'last': 4254269.0, 'volume': 3166.966028429326, 'converted_last': {'btc': 0.01527046, 'eth': 0.20535316, 'usd': 271.94}, 'converted_volume': {'btc': 48.361016, 'eth': 650.346, 'usd': 861239}, 'trust_score': 'green', 'bid_ask_spread_percentage': 0.204474, 'timestamp': '2022-12-14T01:06:51+00:00', 'last_traded_at': '2022-12-14T01:06:51+00:00', 'last_fetch_at': '2022-12-14T01:06:51+00:00', 'is_anomaly': False, 'is_stale': False, 'trade_url': 'https://www.binance.com/en/trade/BNB_BIDR?ref=37754157', 'token_info_url': None, 'coin_id': 'binancecoin', 'target_coin_id': 'binanceidr'}, {'base': 'BNB', 'target': 'BTC', 'market': {'name': 'Binance', 'identifier': 'binance', 'has_trading_incentive': False}, 'last': 0.015326, 'volume': 205149.24947409632, 'converted_last': {'btc': 0.015326, 'eth': 0.20601842, 'usd': 272.84}, 'converted_volume': {'btc': 3144, 'eth': 42265, 'usd': 55971909}, 'trust_score': None, 'bid_ask_spread_percentage': 0.016522, 'timestamp': '2022-12-14T00:59:50+00:00', 'last_traded_at': '2022-12-14T00:59:50+00:00', 'last_fetch_at': '2022-12-14T00:59:50+00:00', 'is_anomaly' ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /opt/conda/envs/vdev/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# /opt/conda/envs/vdev/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#
# /opt/conda/envs/vdev/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /opt/conda/envs/vdev/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_22364/1496773100.py in <module>
#      32
#      33     # return df
# ---> 34 create_exchange_df(exchange, coin_id)
#
# /tmp/ipykernel_22364/1496773100.py in create_exchange_df(exchange, coin_id)
#       4 def create_exchange_df(exchange, coin_id):
#       5     for x in exchange:
# ----> 6         exchange_data = get_coin_data(x, coin_id)
#       7         exchange_df = pd.DataFrame(exchange_data)
#       8     return exchange_df
#
# /tmp/ipykernel_22364/1496773100.py in get_coin_data(exchange, coin_id)
#      13         url = f"https://api.coingecko.com/api/v3/exchanges/{exchange}/tickers?coin_ids={coin}"
#      14         response = requests.get(url)
# ---> 15         data = response.json()
#      16         print (data)
#      17 #         timestamp_list = []
#
# /opt/conda/envs/vdev/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
coin_id = ['bitcoin', 'ethereum', 'tether', 'usd-coin', 'binancecoin']
exchange = ['binance', 'coinbase', 'okx', 'huobi']
 
def create_exchange_df(exchange, coin_id):
    for x in exchange:
        exchange_data = get_coin_data(x, coin_id)
        exchange_df = pd.DataFrame(exchange_data)
    return exchange_df


def get_coin_data (exchange, coin_id):
    for coin in coin_id:
        url = f"https://api.coingecko.com/api/v3/exchanges/{exchange}/tickers?coin_ids={coin}"
        response = requests.get(url)
        data = response.json()
        timestamp_list = []
        price_list = []
        volume_list = []
        price_spread = []
        for row in data['tickers'] :
            # dt = datetime.datetime.fromtimestamp(row[0]/ 1000)
            # formatted_time = dt.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
            # timestamp_list.append(formatted_time)
            # price_list.append(row[1])
            
    raw_data = {'timestamp': timestamp_list, 'price' : price_list}
    df = pd.DataFrame(raw_data, columns=['timestamp','price'])
    df = df.reset_index()
    df = df.set_index('timestamp')
    #pd.options.display.float_format = '{:.2f}'.format
        
    # return df

# %%
url = f"https://api.coingecko.com/api/v3/exchanges/{exchange}/tickers?coin_ids={coin_id}
{
  "name": "Binance",
  "tickers": 
    {
      "base": "BTC",
      "target": "USDT",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last":

      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 17788.99,
      "volume": 78.96450141277273,
      "converted_last": {
        "btc": 0.9995508,
        "eth": 13.456727,
        "usd": 17783.47
      },
      "converted_volume": {
        "btc": 78.929,
        "eth": 1063,
        "usd": 1404263
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.029733,
      "timestamp": "2022-12-13T23:44:41+00:00",
      "last_traded_at": "2022-12-13T23:44:41+00:00",
      "last_fetch_at": "2022-12-13T23:44:41+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_DAI?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin",
      "target_coin_id": "dai"
    },
    {
      "base": "BTC",
      "target": "BIDR",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 277706847,
      "volume": 92.03021945047685,
      "converted_last": {
        "btc": 0.99953224,
        "eth": 13.45412,
        "usd": 17783.68
      },
      "converted_volume": {
        "btc": 91.987,
        "eth": 1238,
        "usd": 1636636
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.094849,
      "timestamp": "2022-12-13T23:41:58+00:00",
      "last_traded_at": "2022-12-13T23:41:58+00:00",
      "last_fetch_at": "2022-12-13T23:41:58+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_BIDR?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin",
      "target_coin_id": "binanceidr"
    },
    {
      "base": "BTC",
      "target": "PLN",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 78688,
      "volume": 35.365258324268,
      "converted_last": {
        "btc": 1.002194,
        "eth": 13.505714,
        "usd": 17813.81
      },
      "converted_volume": {
        "btc": 35.442855,
        "eth": 477.633,
        "usd": 629990
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.160128,
      "timestamp": "2022-12-13T23:57:25+00:00",
      "last_traded_at": "2022-12-13T23:57:25+00:00",
      "last_fetch_at": "2022-12-13T23:57:25+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_PLN?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "ZAR",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 310200,
      "volume": 18.295624082817536,
      "converted_last": {
        "btc": 1.010317,
        "eth": 13.600998,
        "usd": 17975.37
      },
      "converted_volume": {
        "btc": 18.484388,
        "eth": 248.839,
        "usd": 328871
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.143794,
      "timestamp": "2022-12-13T23:37:28+00:00",
      "last_traded_at": "2022-12-13T23:37:28+00:00",
      "last_fetch_at": "2022-12-13T23:40:21+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_ZAR?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "RUB",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 1128698,
      "volume": 21.362843015908595,
      "converted_last": {
        "btc": 1.003558,
        "eth": 13.509773,
        "usd": 17854.91
      },
      "converted_volume": {
        "btc": 21.438855,
        "eth": 288.607,
        "usd": 381432
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.106025,
      "timestamp": "2022-12-13T23:43:15+00:00",
      "last_traded_at": "2022-12-13T23:43:15+00:00",
      "last_fetch_at": "2022-12-13T23:43:15+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_RUB?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "UAH",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 699636,
      "volume": 13.954293136688221,
      "converted_last": {
        "btc": 1.071038,
        "eth": 14.428795,
        "usd": 19039.56
      },
      "converted_volume": {
        "btc": 14.945585,
        "eth": 201.344,
        "usd": 265684
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.198049,
      "timestamp": "2022-12-13T23:54:14+00:00",
      "last_traded_at": "2022-12-13T23:54:14+00:00",
      "last_fetch_at": "2022-12-13T23:56:51+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_UAH?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    }
  ]
}
Response headers
 cache-control: public,max-age=120 
 content-type: application/json; charset=utf-8 
 expires: Wed,14 Dec 2022 00:01:27 GMT 
 per-page:
